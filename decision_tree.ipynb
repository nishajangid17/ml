# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("tennis.csv")

# %%
dataset
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
from sklearn.preprocessing import LabelEncoder

# %%
day=LabelEncoder()
outlook=LabelEncoder()
temp=LabelEncoder()
humidity=LabelEncoder()
wind=LabelEncoder()
play=LabelEncoder()

# %%
dataset["day"]=day.fit_transform(dataset["day"])
dataset["outlook"]=outlook.fit_transform(dataset["outlook"])
dataset["temp"]=temp.fit_transform(dataset["temp"])
dataset["humidity"]=humidity.fit_transform(dataset["humidity"])
dataset["wind"]=wind.fit_transform(dataset["wind"])
dataset["play"]=wind.fit_transform(dataset["play"])

# %%
dataset
# Out:
#     day  outlook  temp  humidity  wind  play
# 0     0        2     1         0     1     0
# 1     6        2     1         0     0     0
# 2     7        0     1         0     1     1
# 3     8        1     2         0     1     1
# 4     9        1     0         1     1     1
# 5    10        1     0         1     0     0
# 6    11        0     0         1     0     1
# 7    12        2     2         0     1     0
# 8    13        2     0         1     1     1
# 9     1        1     2         1     1     1
# 10    2        2     2         1     0     1
# 11    3        0     2         0     0     1
# 12    4        0     1         1     1     1
# 13    5        1     2         0     0     0

# %%
features_cols=["day","outlook","temp","humidity","wind"]
x=dataset[features_cols]

y=dataset["play"]

# %%
x
# Out:
#     day  outlook  temp  humidity  wind
# 0     0        2     1         0     1
# 1     6        2     1         0     0
# 2     7        0     1         0     1
# 3     8        1     2         0     1
# 4     9        1     0         1     1
# 5    10        1     0         1     0
# 6    11        0     0         1     0
# 7    12        2     2         0     1
# 8    13        2     0         1     1
# 9     1        1     2         1     1
# 10    2        2     2         1     0
# 11    3        0     2         0     0
# 12    4        0     1         1     1
# 13    5        1     2         0     0

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# Name: play, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier= DecisionTreeClassifier(criterion="gini")    #entropy also used in creterion

# %%
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
classifier.predict(x_test)
# Out:
# array([0, 1, 0])

# %%
x_test
# Out:
#    day  outlook  temp  humidity  wind
# 0    0        2     1         0     1
# 9    1        1     2         1     1
# 1    6        2     1         0     0

# %%
dataset
# Out:
#     day  outlook  temp  humidity  wind  play
# 0     0        2     1         0     1     0
# 1     6        2     1         0     0     0
# 2     7        0     1         0     1     1
# 3     8        1     2         0     1     1
# 4     9        1     0         1     1     1
# 5    10        1     0         1     0     0
# 6    11        0     0         1     0     1
# 7    12        2     2         0     1     0
# 8    13        2     0         1     1     1
# 9     1        1     2         1     1     1
# 10    2        2     2         1     0     1
# 11    3        0     2         0     0     1
# 12    4        0     1         1     1     1
# 13    5        1     2         0     0     0

# %%
classifier.score(x_train,y_train)
# Out:
# 1.0

# %%
from sklearn import tree
tree.plot_tree(classifier)
# Out:
# [Text(0.4, 0.9, 'x[1] <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.35, 0.8, 'True  '),
#  Text(0.5, 0.7, 'x[3] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.45, 0.8, '  False'),
#  Text(0.2, 0.5, 'x[4] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3, 0.3, 'x[1] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.5, 'x[4] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7, 0.3, 'x[1] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]
