# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("jup.csv")

# %%
dataset.head(7)
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
# 5      6  2d08FB17EE273F4      Aimee     Downs
# 6      7  EA4d384DfDbBf77     Darren      Peck
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
# 5                     Steele Group      Chavezborough
# 6     Lester, Woodard and Mitchell           Lake Ana
#
#                       Country                 Phone 1                Phone 2  \
# ...

# %%
sns.boxplot(x="Index",data=dataset)
# Out:
# <Axes: xlabel='Index'>

# %%
plt.show()

# %%
sns.distplot(dataset["Index"])
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_6960\1379271213.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Index"])
# <Axes: xlabel='Index', ylabel='Density'>

# %%
q1=dataset["Index"].quantile(0.25)
q3=dataset["Index"].quantile(0.75)

# %%
iqr=q3 -q1

# %%
min=q1-(1.5*iqr)
max=q3-(1.5*iqr)

# %%
new=dataset(dataset["Index"])<=max
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 new=dataset(dataset["Index"])<=max
#
# TypeError: 'DataFrame' object is not callable

# %%
dataset
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
dataset["Company"].value_counts()
# Out:
# Company
# Simon LLC                      2
# Rasmussen Group                1
# Knight, Abbott and Hubbard     1
# Parrish Ltd                    1
# Huynh and Sons                 1
#                               ..
# Mcgee Group                    1
# Acosta, Petersen and Morrow    1
# Sawyer PLC                     1
# Santana-Duran                  1
# Le, Nash and Cross             1
# Name: count, Length: 99, dtype: int64

# %%
a=dataset["Company"].replace("East Leonard","nisha",inplace=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 print(a)
#
# NameError: name 'a' is not defined
