# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("term.csv")

# %%
dataset
# Out:
#    AGE  PREMIUM
# 0   25     1800
# 1   30     3200
# 2   35     4200
# 3   40     4700
# 4   45     5500

# %%
x=dataset["AGE"]

# %%
y=dataset["PREMIUM"]

# %%
x
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# 4    45
# Name: AGE, dtype: int64

# %%
y
# Out:
# 0    1800
# 1    3200
# 2    4200
# 3    4700
# 4    5500
# Name: PREMIUM, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=0)

# %%
x_test
# Out:
# 2    35
# 0    25
# 1    30
# Name: AGE, dtype: int64

# %%
x_train
# Out:
# 3    40
# 4    45
# Name: AGE, dtype: int64

# %%
y_test
# Out:
# 2    4200
# 0    1800
# 1    3200
# Name: PREMIUM, dtype: int64

# %%
y_train
# Out:
# 3    4700
# 4    5500
# Name: PREMIUM, dtype: int64
