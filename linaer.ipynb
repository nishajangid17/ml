# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
from sklearn.datasets import load_diabetes

# %%
diabetes_sklearn = load_diabetes()
dataset= pd.DataFrame(data=diabetes_sklearn.data,
                           columns=diabetes_sklearn.feature_names)
dataset['target'] = diabetes_sklearn.target
print(dataset.head())
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
df=load_diabetes()
pd.DataFrame(df.data)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#             7         8         9
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
dataset.columns=dataset.feature_names
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34564\2485214176.py in ?()
# ----> 1 dataset.columns=dataset.feature_names
#
# c:\Users\nisha\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'feature_names'

# %%
dataset.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
## dep and indep
X=dataset
y=df.target
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 ## dep and indep
#       2 X=dataset
# ----> 3 y=df.target
#
# NameError: name 'df' is not defined

# %%
y_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y_test
#
# NameError: name 'y_test' is not defined

# %%
## train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 231  0.009016 -0.044642 -0.030996  0.021872  0.008063  0.008707  0.004460
# 325 -0.001882 -0.044642  0.054152 -0.066506  0.072732  0.056619 -0.043401
# 193  0.009016  0.050680 -0.005128 -0.064199  0.069981  0.083863 -0.039719
# 109  0.038076  0.050680 -0.009439  0.002351  0.001183  0.037517 -0.054446
# 195  0.027178  0.050680  0.025051  0.014987  0.025950  0.048477 -0.039719
# ..        ...       ...       ...       ...       ...       ...       ...
# 106 -0.096328 -0.044642 -0.076264 -0.043542 -0.045599 -0.034821  0.008142
# 270  0.005383  0.050680  0.030440  0.083844 -0.037344 -0.047347  0.015505
# 348  0.030811 -0.044642 -0.020218 -0.005670 -0.004321 -0.029497  0.078093
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 102 -0.092695 -0.044642  0.028284 -0.015999  0.036958  0.024991  0.056003
#
#            s4        s5        s6  target
# ...

# %%
y_train
# Out:
# array([154., 192., 116.,  81., 122., 259., 191., 292.,  55., 107., 210.,
#         91., 253.,  85., 252.,  59.,  78., 200.,  78., 245., 175.,  42.,
#        127.,  53.,  94., 104., 199., 265., 281., 248., 257., 215., 303.,
#        170.,  59., 277., 209., 138., 198., 124.,  96., 288., 225., 265.,
#        101.,  55., 198.,  51., 252.,  64., 220., 131., 212., 142., 103.,
#        155., 121.,  86., 111.,  65., 131.,  51., 128., 141.,  48., 109.,
#        178.,  88.,  84., 216., 150.,  60.,  96., 190.,  74., 279., 182.,
#        160., 245., 276., 174., 180., 150., 196., 138.,  97., 246., 321.,
#        308., 109.,  69., 182., 258., 161., 178., 214.,  45., 150., 160.,
#         55., 197., 185., 268., 310., 123.,  68.,  72., 185., 144., 147.,
#        168., 178., 246., 151., 127.,  83., 332., 152., 109.,  90.,  66.,
#        214.,  85., 129.,  89., 259., 229., 200.,  77.,  54.,  31., 109.,
#        206., 144., 118.,  83., 242., 259.,  72., 163., 181., 141.,  71.,
# ...

# %%
X_test
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 287  0.045341 -0.044642 -0.006206 -0.015999  0.125019  0.125198  0.019187
# 211  0.092564 -0.044642  0.036907  0.021872 -0.024960 -0.016658  0.000779
# 72   0.063504  0.050680 -0.004050 -0.012556  0.103003  0.048790  0.056003
# 321  0.096197 -0.044642  0.051996  0.079265  0.054845  0.036577 -0.076536
# 73   0.012648  0.050680 -0.020218 -0.002228  0.038334  0.053174 -0.006584
# ..        ...       ...       ...       ...       ...       ...       ...
# 346  0.005383  0.050680  0.017506  0.032201  0.127771  0.127390 -0.021311
# 168  0.001751  0.050680  0.059541 -0.002228  0.061725  0.063195 -0.058127
# 393 -0.074533 -0.044642 -0.046085 -0.043542 -0.029088 -0.023234  0.015505
# 141 -0.027310 -0.044642  0.047685 -0.046985  0.034206  0.057245 -0.080217
# 324  0.030811 -0.044642  0.005650  0.011544  0.078236  0.077913 -0.043401
#
#            s4        s5        s6  target
# ...

# %%
y_test
# Out:
# array([219.,  70., 202., 230., 111.,  84., 242., 272.,  94.,  96.,  94.,
#        252.,  99., 297., 135.,  67., 295., 264., 170., 275., 310.,  64.,
#        128., 232., 129., 118., 263.,  77.,  48., 107., 140., 113.,  90.,
#        164., 180., 233.,  42.,  84., 172.,  63.,  48., 108., 156., 168.,
#         90.,  52., 200.,  87.,  90., 258., 136., 158.,  69.,  72., 171.,
#         95.,  72., 151., 168.,  60., 122.,  52., 187., 102., 214., 248.,
#        181., 110., 140., 202., 101., 222., 281.,  61.,  89.,  91., 186.,
#        220., 237., 233.,  68., 190.,  96.,  72., 153.,  98.,  37.,  63.,
#        184., 144., 150., 280., 125.,  59.,  65., 281., 277., 167.,  90.,
#         72., 178.,  88., 270., 101., 197.,  97.,  53.,  71., 262.,  52.,
#        102., 166., 189., 173., 220., 206.,  97.,  60.,  61., 242., 121.,
#        128., 104., 265., 132., 283., 174., 129., 257., 137.,  63.,  93.,
#        232., 208., 261., 179., 258., 262.,  51., 237.,  71., 139., 268.,
# ...

# %%
## standard the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.95678921, -0.94093056, -0.16770818, ...,  0.65964893,
#         -0.15116634,  0.86403674],
#        [ 1.98034352, -0.94093056,  0.73898808, ..., -0.49232917,
#         -0.50558406, -1.05699347],
#        [ 1.35046394,  1.06277768, -0.12237336, ...,  1.75104689,
#         -0.41697963,  0.64485879],
#        ...,
#        [-1.64146405, -0.94093056, -1.00640222, ..., -0.85485446,
#         -0.50558406, -1.06988629],
#        [-0.61790974, -0.94093056,  0.96566215, ...,  0.92451981,
#          2.77277981,  2.12753311],
#        [ 0.64184942, -0.94093056,  0.0816333 , ...,  1.36444243,
#          0.38046023,  1.25082134]])

# %%
X_train
# Out:
# array([[ 0.16943973, -0.94093056, -0.68905853, ...,  0.1774922 ,
#          0.20325138,  0.02600342],
#        [-0.06676511, -0.94093056,  1.10166659, ...,  1.75104689,
#          1.00069124,  0.51593059],
#        [ 0.16943973,  1.06277768, -0.14504077, ...,  0.80871046,
#          0.38046023, -0.46392374],
#        ...,
#        [ 0.64184942, -0.94093056, -0.46238446, ..., -0.248862  ,
#         -0.06256191, -0.0513535 ],
#        [-0.30296995, -0.94093056, -0.53038668, ..., -0.82657099,
#         -0.86000177, -1.13435039],
#        [-2.03513879, -0.94093056,  0.55764883, ..., -0.12808394,
#         -0.06256191,  1.93414081]])

# %%
from sklearn.linear_model import LinearRegression
## cross validation
from sklearn.model_selection import cross_val_score

regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
mse=cross_val_score(regression,X_train,y_train,scoring="neg_mean_squared_error",cv=10)

# %%
np.mean(mse)
# Out:
# -5.188959469606706e-27

# %%
## prediction
reg_pred=regression.predict(X_test)
# Out:
# c:\Users\nisha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
reg_pred
# Out:
# array([ 0.86403674, -1.05699347,  0.64485879,  1.00585776, -0.52838784,
#        -0.87649399,  1.1605716 ,  1.54735621, -0.74756579, -0.72178015,
#        -0.74756579,  1.2894998 , -0.68310169,  1.86967671, -0.21896016,
#        -1.09567193,  1.84389107,  1.44421364,  0.23228855,  1.58603467,
#         2.03728337, -1.13435039, -0.3092099 ,  1.0316434 , -0.29631708,
#        -0.4381381 ,  1.43132082, -0.96674373, -1.34063552, -0.57995912,
#        -0.15449606, -0.5026022 , -0.79913707,  0.15493163,  0.36121675,
#         1.04453622, -1.41799244, -0.87649399,  0.25807419, -1.14724321,
#        -1.34063552, -0.5670663 ,  0.05178906,  0.20650291, -0.79913707,
#        -1.28906423,  0.61907315, -0.83781553, -0.79913707,  1.36685672,
#        -0.20606734,  0.07757471, -1.06988629, -1.03120783,  0.24518137,
#        -0.73467297, -1.03120783, -0.01267504,  0.20650291, -1.18592167,
#        -0.38656682, -1.28906423,  0.45146649, -0.64442323,  0.79957264,
# ...

# %%
sns.displot(reg_pred-y_test,kind='kde')

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(reg_pred,y_test)

# %%
score
# Out:
# -30148.965054283035

# %% [markdown]
# ridge regression algorithm

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
ridge_reg=Ridge()

# %%
ridge_reg
# Out:
# Ridge()

# %%
parameters={'alpha':[15,10,8,3,13,1,5,10,20,30,35,40]}
ridgecv=GridSearchCV(ridge_reg,parameters,scoring='neg_mean_squared_error',cv=5)
ridgecv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [15, 10, 8, 3, 13, 1, 5, 10, 20, 30, 35, 40]},
#              scoring='neg_mean_squared_error')

# %%
print(ridgecv.best_params_)
# Out:
# {'alpha': 1}

# %%
print(ridgecv.best_score_)
# Out:
# -0.23512429975750382

# %%
ridge_pred=ridgecv.predict(X_test)

# %%
sns.displot(ridge_pred-y_test,kind='kde')

# %%
score=r2_score(ridge_pred,y_test)

# %%
score
# Out:
# 0.9999770443340364

# %%
## lasssoo algorithm
from sklearn.linear_model import Lasso
lasso=Lasso()
parameters={'alpha':[15,10,8,3,13,1,5,10,20,30,35,40]}
lassocv=GridSearchCV(ridge_reg,parameters,scoring='neg_mean_squared_error',cv=5)
lassocv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [15, 10, 8, 3, 13, 1, 5, 10, 20, 30, 35, 40]},
#              scoring='neg_mean_squared_error')

# %%
print(lassocv.best_params_)
print(lassocv.best_score_)
# Out:
# {'alpha': 1}
# -0.23512429975750382

# %%
lasso_pred=lassocv.predict(X_test)

# %%
sns.displot(lasso_pred-y_test,kind='kde')

# %%
from matplotlib import ListedColormap

# %%
X_set,y_set=X_train,y_train
